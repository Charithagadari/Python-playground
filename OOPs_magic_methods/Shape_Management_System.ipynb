# %% [markdown]
# Background
#
# You are building a geometry library for a graphics application. Different shapes have different ways of calculating area and perimeter, but they should all follow a common interface.
#
# Design the system using Object-Oriented Programming principles.

# %% [markdown]
# Requirements
# Part 1: Abstract Base Class
#
# Create an abstract class called Shape.
#
# It should contain the following:
#
# Attributes
# name (string)
# color (string)
#
# These attributes should be private.
#
# Constructor
#
# The constructor should initialize :
#
# name
# color
#
# Methods :
# Getter Methods
# get_name()
# get_color()
#
# Setter Methods:
# set_name(name)
# set_color(color)
#
# Validation:
#
# Name cannot be empty.
# Color cannot be empty.
#
# Raise a ValueError if validation fails.
#
# Abstract Methods
#
# Every shape must implement:
#
# area()
# perimeter()
# Concrete Method
#
# Implement
#
# display_info()
#
# which prints
#
# Shape : Circle
# Color : Red
# Area : ...
# Perimeter : ...
#
# Notice that display_info() should work correctly for every subclass without modification.

# %%
class Shape:
    def __init__(self, name, color):
        self.__color = color
        self.__name = name
    
    def Shape(self):
